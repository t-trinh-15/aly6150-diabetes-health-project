# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))

# %load_ext autoreload
# %autoreload 2

import pandas as pd
from src.config import DATA_PROCESSED, OUTPUT_FIGURES

meps = pd.read_csv(DATA_PROCESSED / "meps_diabetes_2023_clean.csv")
brfss = pd.read_csv(DATA_PROCESSED / "brfss_diabetes_2023_clean.csv")

print(f"MEPS : {len(meps):,} rows")
print(f"BRFSS: {len(brfss):,} rows")
print(f"Output: {OUTPUT_FIGURES}")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# MEPS : 812 rows
# BRFSS: 1,983 rows
# Output: /Users/ht/Desktop/aly6150_diabetes_project/aly6150-diabetes-health-project/outputs/figures

# %%
from src.visualization import build_all_charts

chart_paths = build_all_charts(meps, brfss, OUTPUT_FIGURES)
# Out:
# Building charts...
#   ✓ 01_meps_cost_composition.png
#   ✓ 02_brfss_missed_care_by_insurance.png
#
# Both charts saved to: /Users/ht/Desktop/aly6150_diabetes_project/aly6150-diabetes-health-project/outputs/figures
# /Users/ht/Desktop/aly6150_diabetes_project/aly6150-diabetes-health-project/src/visualization.py:119: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   [f"{lbl}\n(n={n:,})" for lbl, n in zip(g["label"], g["n"])],
